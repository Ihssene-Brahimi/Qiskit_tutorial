# %% [markdown]
# <a href="https://colab.research.google.com/github/Ihssene-Brahimi/Qiskit_tutorial/blob/main/Qiskit_Foundations_%E2%80%8APart_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Qiskit Foundations - Part II**

# %%
# !pip install qiskit

# %%
# !pip install pylatexenc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 162 kB 5.3 MB/s
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136835 sha256=18227ca97ad9318a0320a973a639c91a8be52e6b9647458da2cc31b670b53aec
#   Stored in directory: /root/.cache/pip/wheels/f1/8a/f5/33ee79d4473eb201b519fa40f989b842e373237395a3421f52
# Successfully built pylatexenc
# ...

# %%
from qiskit import *

# %%
from qiskit.providers.basicaer import statevector_simulator
circuit = QuantumCircuit(1,1)
circuit.x(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend = simulator).result()
statevector = result.get_statevector()
print(statevector)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
# %matplotlib
circuit.draw(output = 'mpl')
# Out:
# Using matplotlib backend: agg

# %%
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(statevector)

# %%
from qiskit.providers import backend
circuit.measure([0],[0])
backend = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend = backend, shots = 1024).result()
counts = result.get_counts()
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)

# %%
circuit = QuantumCircuit(1,1)
circuit.x(0)
simulator = Aer.get_backend('unitary_simulator')
result = execute(circuit, backend = simulator).result()
unitary = result.get_unitary()
print(unitary)
# Out:
# Operator([[0.+0.j, 1.+0.j],
#           [1.+0.j, 0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# # **Quantum Teleportation**

# %%
circuit = QuantumCircuit(3, 3)

# %%
# %matplotlib
circuit.draw(output = 'mpl')
# Out:
# Using matplotlib backend: agg

# %%
circuit.x(0)
circuit.barrier()
circuit.draw(output = 'mpl')

# %%
circuit.h(1)
circuit.cx(1, 2)
circuit.draw(output = 'mpl')

# %%
circuit.cx(0, 1)
circuit.h(0)
circuit.draw(output = 'mpl')

# %%
circuit.barrier()
circuit.measure([0, 1], [0, 1])
circuit.draw(output = 'mpl')

# %%
circuit.barrier()
circuit.cx(1, 2)
circuit.cz(0, 2)
circuit.draw(output = 'mpl')

# %%
circuit.measure(2,2)
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend = simulator, shots = 1024).result()
counts = result.get_counts(circuit)
plot_histogram(counts)

# %%
print(counts)
# Out:
# {'111': 263, '110': 261, '100': 252, '101': 248}
